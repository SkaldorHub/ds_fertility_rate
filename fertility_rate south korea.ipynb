# %%
# !/usr/bin/python3 -m pip install pandas xlrd matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/johannes/.local/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: xlrd in /home/johannes/.local/lib/python3.10/site-packages (2.0.2)
# Requirement already satisfied: matplotlib in /home/johannes/.local/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/johannes/.local/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/johannes/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/johannes/.local/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /home/johannes/.local/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/johannes/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /home/johannes/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/johannes/.local/lib/python3.10/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in /home/johannes/.local/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/johannes/.local/lib/python3.10/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/johannes/.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import os

# create output folder
os.makedirs("diagram_output", exist_ok=True)
# Out:
# /home/johannes/.local/lib/python3.10/site-packages/numpy/_core/getlimits.py:551: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %% [markdown]
# ## Load Excel and create diagram

# %%
output = pd.read_excel("fertility_rates.xls", sheet_name="Data", index_col=0, skiprows=3)
countries = ["Sweden", "Niger", "China", "Brazil", "Korea, Rep."]
for country in countries:
    print(country)
    country_data = output.loc[country] ###

    # Get x/y values
    years = country_data.index[3:]  # skip first 3 columns ###
    fertility_rates = country_data[3:].values

    # Create diagram
    plt.plot(years, fertility_rates) #, marker='o', markersize=4

    # Configure diagram
    plt.xticks(years[::10], rotation=45)  # Zeige nur jedes 10. Jahr und drehe die Beschriftungen für bessere Lesbarkeit
    plt.title(f"Fertility Rate in {country} (1960–2023)") ###
    plt.xlabel("Year")
    plt.ylabel("Fertility Rate (births per woman)")
    plt.grid(True)
    plt.tight_layout()

    # Save diagram as .png
    plt.savefig(f"diagram_output/{country}_fertility_rate.png", dpi=1200) ###

    # Show diagram
    #plt.show()
# Out:
# Sweden
# Niger
# China
# Brazil
# Korea, Rep.

# %% [markdown]
# ## World comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read Data
output = pd.read_excel("fertility_rates.xls", sheet_name="Data", index_col=0, skiprows=3)
south_korea_data = output.loc["Korea, Rep."]
world_data = output.loc["World"]

# X-Values (years9

# Y-Values
south_korea_rates = south_korea_data[3:].values
world_rates = world_data[3:].values

# Create diagram
plt.plot(years, south_korea_rates, label="Südkorea")
plt.plot(years, world_rates, label="Welt")

# Configure diagram
plt.xticks(years[::10], rotation=45)
plt.title("TFR: Südkorea vs. Welt (1960–2023)")
plt.xlabel("Jahr")
plt.ylabel("TFR (Geburten pro Frau)")
plt.grid(True)
plt.legend()
plt.tight_layout()

# Save diagram
plt.savefig("diagram_output/world_fertility_rate.png", dpi=1200)

# Show diagram
# plt.show()
